# %%
#mushroom data set decision tree
import pandas as pd
import numpy as np
user = "bfo"
mushroom_dataframe = pd.read_csv(f"C:/Users/{user}/Downloads/mushrooms.csv", delimiter = ';')
mushroom_dataframe
mushroom_dataframe.head()
# Out:
#   class  cap_diameter cap_shape cap_surface cap_color does_bruise_or_bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill_attachment gill_spacing gill_color  stem_height  ...  stem_root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem_surface stem_color veil_type veil_color has_ring ring_type  \
# 0            y          w         u          w        t         g
# 1            y          w         u          w        t         g
# 2            y          w         u          w        t         g
# 3            y          w         u          w        t         p
# 4            y          w         u          w        t         p
#
#   spore_print_color habitat season
# 0               NaN       d      w
# 1               NaN       d      u
# 2               NaN       d      w
# 3               NaN       d      w
# 4               NaN       d      w
#
# [5 rows x 21 columns]

# %%
mushroom_dataframe.columns
# Out:
# Index(['class', 'cap_diameter', 'cap_shape', 'cap_surface', 'cap_color',
#        'does_bruise_or_bleed', 'gill_attachment', 'gill_spacing', 'gill_color',
#        'stem_height', 'stem_width', 'stem_root', 'stem_surface', 'stem_color',
#        'veil_type', 'veil_color', 'has_ring', 'ring_type', 'spore_print_color',
#        'habitat', 'season'],
#       dtype='object')

# %%
mushroom_dataframe = mushroom_dataframe.rename(columns={'class':"class", 'cap-diameter':"cap_diameter", 'cap-shape':"cap_shape", 'cap-surface':"cap_surface", 'capcolor':"cap_color", 
'does-bruise-or-bleed':"does_bruise_or_bleed", 'gill-attachment':"gill_attachment", 'gill-spacing':"gill_spacing", 'gill-color':"gill_color", 'stemheight':"stem_height", 
'stem-width':"stem_width", 'stem-root':"stem_root", 'stem-surface':"stem_surface", 'stem-color':"stem_color", 'veil-type':"veil_type", 'veilcolor':"veil_color", 
'has-ring':"has_ring", 'ring-type':"ring_type", 'spore-print-color':"Spore_print_color", 'habitat':"habitat", 'season':"season"})

# %%
import sklearn as sl
from sklearn.model_selection import train_test_split
x = mushroom_dataframe.drop("class", axis=1)
x
# Out:
#        cap_diameter cap_shape cap_surface cap_color does_bruise_or_bleed  \
# 0             15.26         x           g         o                    f
# 1             16.60         x           g         o                    f
# 2             14.07         x           g         o                    f
# 3             14.17         f           h         e                    f
# 4             14.64         x           h         o                    f
# ...             ...       ...         ...       ...                  ...
# 61064          1.18         s           s         y                    f
# 61065          1.27         f           s         y                    f
# 61066          1.27         s           s         y                    f
# 61067          1.24         f           s         y                    f
# 61068          1.17         s           s         y                    f
#
#       gill_attachment gill_spacing gill_color  stem_height  stem_width  \
# 0                   e          NaN          w        16.95       17.09
# 1                   e          NaN          w        17.99       18.19
# 2                   e          NaN          w        17.80       17.74
# 3                   e          NaN          w        15.77       15.98
# 4                   e          NaN          w        16.53       17.20
# ...               ...          ...        ...          ...         ...
# 61064               f            f          f         3.93        6.22
# 61065               f            f          f         3.18        5.43
# 61066               f            f          f         3.86        6.37
# 61067               f            f          f         3.56        5.44
# 61068               f            f          f         3.25        5.45
#
#       stem_root stem_surface stem_color veil_type veil_color has_ring  \
# 0             s            y          w         u          w        t
# 1             s            y          w         u          w        t
# 2             s            y          w         u          w        t
# 3             s            y          w         u          w        t
# 4             s            y          w         u          w        t
# ...         ...          ...        ...       ...        ...      ...
# 61064       NaN          NaN          y       NaN        NaN        f
# 61065       NaN          NaN          y       NaN        NaN        f
# 61066       NaN          NaN          y       NaN        NaN        f
# 61067       NaN          NaN          y       NaN        NaN        f
# 61068       NaN          NaN          y       NaN        NaN        f
#
#       ring_type spore_print_color habitat season
# 0             g               NaN       d      w
# 1             g               NaN       d      u
# 2             g               NaN       d      w
# 3             p               NaN       d      w
# 4             p               NaN       d      w
# ...         ...               ...     ...    ...
# 61064         f               NaN       d      a
# 61065         f               NaN       d      a
# 61066         f               NaN       d      u
# 61067         f               NaN       d      u
# 61068         f               NaN       d      u
#
# [61069 rows x 20 columns]

# %%
x.cap_shape=mushroom_dataframe.cap_shape.astype('category').cat.codes
x.cap_surface=mushroom_dataframe.cap_surface.astype('category').cat.codes
x.cap_color=mushroom_dataframe.cap_color.astype('category').cat.codes
x.gill_attachment=mushroom_dataframe.gill_attachment.astype('category').cat.codes
x.does_bruise_or_bleed=mushroom_dataframe.does_bruise_or_bleed.astype('category').cat.codes
x.gill_spacing=mushroom_dataframe.gill_spacing.astype('category').cat.codes
x.gill_color=mushroom_dataframe.gill_color.astype('category').cat.codes
x.stem_root=mushroom_dataframe.stem_root.astype('category').cat.codes
x.stem_surface=mushroom_dataframe.stem_surface.astype('category').cat.codes
x.stem_color=mushroom_dataframe.stem_color.astype('category').cat.codes
x.veil_type=mushroom_dataframe.veil_type.astype('category').cat.codes
x.veil_color=mushroom_dataframe.veil_color.astype('category').cat.codes
x.has_ring=mushroom_dataframe.has_ring.astype('category').cat.codes
x.ring_type=mushroom_dataframe.ring_type.astype('category').cat.codes
x.spore_print_color=mushroom_dataframe.spore_print_color.astype('category').cat.codes
x.habitat=mushroom_dataframe.habitat.astype('category').cat.codes
x.season=mushroom_dataframe.season.astype('category').cat.codes
x
# Out:
#        cap_diameter  cap_shape  cap_surface  cap_color  does_bruise_or_bleed  \
# 0             15.26          6            2          6                     0
# 1             16.60          6            2          6                     0
# 2             14.07          6            2          6                     0
# 3             14.17          2            3          1                     0
# 4             14.64          6            3          6                     0
# ...             ...        ...          ...        ...                   ...
# 61064          1.18          5            7         11                     0
# 61065          1.27          2            7         11                     0
# 61066          1.27          5            7         11                     0
# 61067          1.24          2            7         11                     0
# 61068          1.17          5            7         11                     0
#
#        gill_attachment  gill_spacing  gill_color  stem_height  stem_width  \
# 0                    2            -1          10        16.95       17.09
# 1                    2            -1          10        17.99       18.19
# 2                    2            -1          10        17.80       17.74
# 3                    2            -1          10        15.77       15.98
# 4                    2            -1          10        16.53       17.20
# ...                ...           ...         ...          ...         ...
# 61064                3             2           2         3.93        6.22
# 61065                3             2           2         3.18        5.43
# 61066                3             2           2         3.86        6.37
# 61067                3             2           2         3.56        5.44
# 61068                3             2           2         3.25        5.45
#
#        stem_root  stem_surface  stem_color  veil_type  veil_color  has_ring  \
# 0              4             7          11          0           4         1
# 1              4             7          11          0           4         1
# 2              4             7          11          0           4         1
# 3              4             7          11          0           4         1
# 4              4             7          11          0           4         1
# ...          ...           ...         ...        ...         ...       ...
# 61064         -1            -1          12         -1          -1         0
# 61065         -1            -1          12         -1          -1         0
# 61066         -1            -1          12         -1          -1         0
# 61067         -1            -1          12         -1          -1         0
# 61068         -1            -1          12         -1          -1         0
#
#        ring_type  spore_print_color  habitat  season
# 0              2                 -1        0       3
# 1              2                 -1        0       2
# 2              2                 -1        0       3
# 3              5                 -1        0       3
# 4              5                 -1        0       3
# ...          ...                ...      ...     ...
# 61064          1                 -1        0       0
# 61065          1                 -1        0       0
# 61066          1                 -1        0       2
# 61067          1                 -1        0       2
# 61068          1                 -1        0       2
#
# [61069 rows x 20 columns]

# %%
df_label = mushroom_dataframe["class"].copy()
y=np.ravel(df_label)
y
# Out:
# array(['p', 'p', 'p', ..., 'p', 'p', 'p'], dtype=object)

# %%
#check if dataset label are balanced
df_label.value_counts()
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.5, random_state=50)

# %%
from sklearn.datasets import load_iris
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)
tree.plot_tree(clf)
# Out:
# [Text(0.5759791666666667, 0.975, 'X[9] <= 8.225\ngini = 0.494\nsamples = 30534\nvalue = [13560, 16974]'),
#  Text(0.33516666666666667, 0.925, 'X[6] <= 0.5\ngini = 0.426\nsamples = 12976\nvalue = [3992, 8984]'),
#  Text(0.21366666666666667, 0.875, 'X[2] <= 3.5\ngini = 0.364\nsamples = 10178\nvalue = [2432, 7746]'),
#  Text(0.09133333333333334, 0.825, 'X[1] <= 0.5\ngini = 0.446\nsamples = 5152\nvalue = [1730, 3422]'),
#  Text(0.038, 0.775, 'X[8] <= 3.675\ngini = 0.179\nsamples = 958\nvalue = [95, 863]'),
#  Text(0.027333333333333334, 0.725, 'X[2] <= 2.5\ngini = 0.13\nsamples = 100\nvalue = [93, 7]'),
#  Text(0.022, 0.675, 'gini = 0.0\nsamples = 93\nvalue = [93, 0]'),
#  Text(0.03266666666666666, 0.675, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.048666666666666664, 0.725, 'X[8] <= 3.765\ngini = 0.005\nsamples = 858\nvalue = [2, 856]'),
#  Text(0.043333333333333335, 0.675, 'X[7] <= 4.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.038, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.048666666666666664, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.054, 0.675, 'gini = 0.0\nsamples = 847\nvalue = [0, 847]'),
#  Text(0.14466666666666667, 0.775, 'X[14] <= 1.5\ngini = 0.476\nsamples = 4194\nvalue = [1635, 2559]'),
#  Text(0.13933333333333334, 0.725, 'X[12] <= 3.5\ngini = 0.459\nsamples = 3974\nvalue = [1415, 2559]'),
#  Text(0.07, 0.675, 'X[0] <= 4.46\ngini = 0.386\nsamples = 433\nvalue = [320, 113]'),
#  Text(0.059333333333333335, 0.625, 'X[2] <= -0.5\ngini = 0.025\nsamples = 319\nvalue = [315, 4]'),
#  Text(0.054, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06466666666666666, 0.575, 'gini = 0.0\nsamples = 315\nvalue = [315, 0]'),
#  Text(0.08066666666666666, 0.625, 'X[5] <= 0.5\ngini = 0.084\nsamples = 114\nvalue = [5, 109]'),
#  Text(0.07533333333333334, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.086, 0.575, 'gini = 0.0\nsamples = 109\nvalue = [0, 109]'),
#  Text(0.20866666666666667, 0.675, 'X[4] <= 0.5\ngini = 0.427\nsamples = 3541\nvalue = [1095, 2446]'),
#  Text(0.15333333333333332, 0.625, 'X[0] <= 3.925\ngini = 0.389\nsamples = 3157\nvalue = [834, 2323]'),
#  Text(0.09666666666666666, 0.575, 'X[7] <= 3.5\ngini = 0.215\nsamples = 1932\nvalue = [237, 1695]'),
#  Text(0.07733333333333334, 0.525, 'X[16] <= 0.5\ngini = 0.057\nsamples = 103\nvalue = [100, 3]'),
#  Text(0.072, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08266666666666667, 0.475, 'gini = 0.0\nsamples = 100\nvalue = [100, 0]'),
#  Text(0.116, 0.525, 'X[11] <= 5.5\ngini = 0.139\nsamples = 1829\nvalue = [137, 1692]'),
#  Text(0.09333333333333334, 0.475, 'X[9] <= 7.495\ngini = 0.093\nsamples = 1690\nvalue = [83, 1607]'),
#  Text(0.064, 0.425, 'X[9] <= 4.16\ngini = 0.066\nsamples = 1644\nvalue = [56, 1588]'),
#  Text(0.034666666666666665, 0.375, 'X[0] <= 3.655\ngini = 0.022\nsamples = 1415\nvalue = [16, 1399]'),
#  Text(0.021333333333333333, 0.325, 'X[0] <= 3.435\ngini = 0.007\nsamples = 1368\nvalue = [5, 1363]'),
#  Text(0.010666666666666666, 0.275, 'X[0] <= 3.205\ngini = 0.002\nsamples = 1301\nvalue = [1, 1300]'),
#  Text(0.005333333333333333, 0.225, 'gini = 0.0\nsamples = 1239\nvalue = [0, 1239]'),
#  Text(0.016, 0.225, 'X[0] <= 3.215\ngini = 0.032\nsamples = 62\nvalue = [1, 61]'),
#  Text(0.010666666666666666, 0.175, 'X[2] <= -0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.005333333333333333, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.016, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.021333333333333333, 0.175, 'gini = 0.0\nsamples = 60\nvalue = [0, 60]'),
#  Text(0.032, 0.275, 'X[12] <= 10.5\ngini = 0.112\nsamples = 67\nvalue = [4, 63]'),
#  Text(0.02666666666666667, 0.225, 'gini = 0.0\nsamples = 60\nvalue = [0, 60]'),
#  Text(0.037333333333333336, 0.225, 'X[5] <= 3.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.032, 0.175, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.042666666666666665, 0.175, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.048, 0.325, 'X[12] <= 9.5\ngini = 0.359\nsamples = 47\nvalue = [11, 36]'),
#  Text(0.042666666666666665, 0.275, 'gini = 0.0\nsamples = 35\nvalue = [0, 35]'),
#  Text(0.05333333333333334, 0.275, 'X[11] <= 1.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.048, 0.225, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.058666666666666666, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09333333333333334, 0.375, 'X[7] <= 6.5\ngini = 0.288\nsamples = 229\nvalue = [40, 189]'),
#  Text(0.08, 0.325, 'X[1] <= 5.5\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.07466666666666667, 0.275, 'X[1] <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.06933333333333333, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08, 0.225, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08533333333333333, 0.275, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.10666666666666667, 0.325, 'X[7] <= 10.5\ngini = 0.161\nsamples = 204\nvalue = [18, 186]'),
#  Text(0.096, 0.275, 'X[11] <= 2.0\ngini = 0.117\nsamples = 192\nvalue = [12, 180]'),
#  Text(0.09066666666666667, 0.225, 'X[12] <= 5.5\ngini = 0.1\nsamples = 190\nvalue = [10, 180]'),
#  Text(0.08533333333333333, 0.175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.096, 0.175, 'X[9] <= 4.19\ngini = 0.081\nsamples = 188\nvalue = [8, 180]'),
#  Text(0.08533333333333333, 0.125, 'X[1] <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09066666666666667, 0.075, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10666666666666667, 0.125, 'X[7] <= 9.0\ngini = 0.063\nsamples = 185\nvalue = [6, 179]'),
#  Text(0.10133333333333333, 0.075, 'X[12] <= 8.5\ngini = 0.291\nsamples = 34\nvalue = [6, 28]'),
#  Text(0.096, 0.025, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.10666666666666667, 0.025, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.112, 0.075, 'gini = 0.0\nsamples = 151\nvalue = [0, 151]'),
#  Text(0.10133333333333333, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11733333333333333, 0.275, 'X[2] <= -0.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.112, 0.225, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.12266666666666666, 0.225, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.12266666666666666, 0.425, 'X[1] <= 5.5\ngini = 0.485\nsamples = 46\nvalue = [27, 19]'),
#  Text(0.11733333333333333, 0.375, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.128, 0.375, 'X[8] <= 5.97\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.12266666666666666, 0.325, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.13333333333333333, 0.325, 'X[8] <= 6.59\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.128, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13866666666666666, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13866666666666666, 0.475, 'X[9] <= 3.615\ngini = 0.475\nsamples = 139\nvalue = [54, 85]'),
#  Text(0.13333333333333333, 0.425, 'gini = 0.0\nsamples = 53\nvalue = [53, 0]'),
#  Text(0.144, 0.425, 'X[5] <= 5.5\ngini = 0.023\nsamples = 86\nvalue = [1, 85]'),
#  Text(0.13866666666666666, 0.375, 'gini = 0.0\nsamples = 85\nvalue = [0, 85]'),
#  Text(0.14933333333333335, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21, 0.575, 'X[7] <= 10.5\ngini = 0.5\nsamples = 1225\nvalue = [597, 628]'),
#  Text(0.19333333333333333, 0.525, 'X[8] <= 7.76\ngini = 0.492\nsamples = 1051\nvalue = [592, 459]'),
#  Text(0.188, 0.475, 'X[8] <= 5.255\ngini = 0.472\nsamples = 957\nvalue = [592, 365]'),
#  Text(0.17066666666666666, 0.425, 'X[11] <= 4.0\ngini = 0.48\nsamples = 444\nvalue = [178, 266]'),
#  Text(0.16, 0.375, 'X[1] <= 5.5\ngini = 0.185\nsamples = 233\nvalue = [24, 209]'),
#  Text(0.15466666666666667, 0.325, 'gini = 0.0\nsamples = 185\nvalue = [0, 185]'),
#  Text(0.16533333333333333, 0.325, 'X[7] <= 9.0\ngini = 0.5\nsamples = 48\nvalue = [24, 24]'),
#  Text(0.16, 0.275, 'X[0] <= 5.42\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.15466666666666667, 0.225, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.16533333333333333, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17066666666666666, 0.275, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.18133333333333335, 0.375, 'X[5] <= 0.5\ngini = 0.394\nsamples = 211\nvalue = [154, 57]'),
#  Text(0.176, 0.325, 'gini = 0.0\nsamples = 45\nvalue = [0, 45]'),
#  Text(0.18666666666666668, 0.325, 'X[10] <= -0.5\ngini = 0.134\nsamples = 166\nvalue = [154, 12]'),
#  Text(0.18133333333333335, 0.275, 'X[3] <= 4.5\ngini = 0.013\nsamples = 155\nvalue = [154, 1]'),
#  Text(0.176, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18666666666666668, 0.225, 'gini = 0.0\nsamples = 154\nvalue = [154, 0]'),
#  Text(0.192, 0.275, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.20533333333333334, 0.425, 'X[3] <= 3.0\ngini = 0.311\nsamples = 513\nvalue = [414, 99]'),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.21066666666666667, 0.375, 'X[16] <= 0.5\ngini = 0.245\nsamples = 483\nvalue = [414, 69]'),
#  Text(0.20533333333333334, 0.325, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.216, 0.325, 'X[16] <= 6.5\ngini = 0.157\nsamples = 453\nvalue = [414, 39]'),
#  Text(0.21066666666666667, 0.275, 'X[7] <= 9.5\ngini = 0.126\nsamples = 444\nvalue = [414, 30]'),
#  Text(0.19733333333333333, 0.225, 'X[8] <= 7.25\ngini = 0.032\nsamples = 304\nvalue = [299, 5]'),
#  Text(0.18666666666666668, 0.175, 'X[8] <= 7.005\ngini = 0.007\nsamples = 292\nvalue = [291, 1]'),
#  Text(0.18133333333333335, 0.125, 'gini = 0.0\nsamples = 283\nvalue = [283, 0]'),
#  Text(0.192, 0.125, 'X[9] <= 3.89\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.18666666666666668, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19733333333333333, 0.075, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.208, 0.175, 'X[12] <= 8.5\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.20266666666666666, 0.125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.21333333333333335, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.224, 0.225, 'X[6] <= -0.5\ngini = 0.293\nsamples = 140\nvalue = [115, 25]'),
#  Text(0.21866666666666668, 0.175, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.22933333333333333, 0.175, 'X[10] <= -0.5\ngini = 0.017\nsamples = 116\nvalue = [115, 1]'),
#  Text(0.224, 0.125, 'gini = 0.0\nsamples = 115\nvalue = [115, 0]'),
#  Text(0.23466666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22133333333333333, 0.275, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.19866666666666666, 0.475, 'gini = 0.0\nsamples = 94\nvalue = [0, 94]'),
#  Text(0.22666666666666666, 0.525, 'X[2] <= -0.5\ngini = 0.056\nsamples = 174\nvalue = [5, 169]'),
#  Text(0.22133333333333333, 0.475, 'X[0] <= 6.325\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.216, 0.425, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.22666666666666666, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.232, 0.475, 'gini = 0.0\nsamples = 168\nvalue = [0, 168]'),
#  Text(0.264, 0.625, 'X[0] <= 4.19\ngini = 0.435\nsamples = 384\nvalue = [261, 123]'),
#  Text(0.24266666666666667, 0.575, 'X[2] <= -0.5\ngini = 0.079\nsamples = 268\nvalue = [257, 11]'),
#  Text(0.23733333333333334, 0.525, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.248, 0.525, 'X[0] <= 3.915\ngini = 0.015\nsamples = 259\nvalue = [257, 2]'),
#  Text(0.24266666666666667, 0.475, 'gini = 0.0\nsamples = 246\nvalue = [246, 0]'),
#  Text(0.25333333333333335, 0.475, 'X[7] <= 8.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.248, 0.425, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.25866666666666666, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2853333333333333, 0.575, 'X[3] <= 6.0\ngini = 0.067\nsamples = 116\nvalue = [4, 112]'),
#  Text(0.28, 0.525, 'X[0] <= 4.405\ngini = 0.018\nsamples = 113\nvalue = [1, 112]'),
#  Text(0.27466666666666667, 0.475, 'X[0] <= 4.35\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.2693333333333333, 0.425, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.28, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2853333333333333, 0.475, 'gini = 0.0\nsamples = 106\nvalue = [0, 106]'),
#  Text(0.2906666666666667, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15, 0.725, 'gini = 0.0\nsamples = 220\nvalue = [220, 0]'),
#  Text(0.336, 0.825, 'X[12] <= 6.5\ngini = 0.24\nsamples = 5026\nvalue = [702, 4324]'),
#  Text(0.296, 0.775, 'X[12] <= 1.5\ngini = 0.034\nsamples = 2072\nvalue = [36, 2036]'),
#  Text(0.2853333333333333, 0.725, 'X[2] <= 5.5\ngini = 0.266\nsamples = 190\nvalue = [30, 160]'),
#  Text(0.28, 0.675, 'gini = 0.0\nsamples = 160\nvalue = [0, 160]'),
#  Text(0.2906666666666667, 0.675, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.30666666666666664, 0.725, 'X[3] <= 0.5\ngini = 0.006\nsamples = 1882\nvalue = [6, 1876]'),
#  Text(0.30133333333333334, 0.675, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.312, 0.675, 'X[9] <= 8.085\ngini = 0.003\nsamples = 1879\nvalue = [3, 1876]'),
#  Text(0.30133333333333334, 0.625, 'X[9] <= 7.655\ngini = 0.001\nsamples = 1833\nvalue = [1, 1832]'),
#  Text(0.296, 0.575, 'gini = 0.0\nsamples = 1710\nvalue = [0, 1710]'),
#  Text(0.30666666666666664, 0.575, 'X[8] <= 4.02\ngini = 0.016\nsamples = 123\nvalue = [1, 122]'),
#  Text(0.30133333333333334, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.312, 0.525, 'gini = 0.0\nsamples = 122\nvalue = [0, 122]'),
#  Text(0.32266666666666666, 0.625, 'X[8] <= 5.345\ngini = 0.083\nsamples = 46\nvalue = [2, 44]'),
#  Text(0.31733333333333336, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.328, 0.575, 'X[18] <= 2.0\ngini = 0.043\nsamples = 45\nvalue = [1, 44]'),
#  Text(0.32266666666666666, 0.525, 'gini = 0.0\nsamples = 40\nvalue = [0, 40]'),
#  Text(0.3333333333333333, 0.525, 'X[5] <= 5.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.328, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.33866666666666667, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.376, 0.775, 'X[15] <= 0.5\ngini = 0.349\nsamples = 2954\nvalue = [666, 2288]'),
#  Text(0.37066666666666664, 0.725, 'X[18] <= 0.5\ngini = 0.435\nsamples = 2084\nvalue = [666, 1418]'),
#  Text(0.36, 0.675, 'X[5] <= 0.5\ngini = 0.498\nsamples = 1007\nvalue = [538, 469]'),
#  Text(0.3546666666666667, 0.625, 'X[9] <= 4.005\ngini = 0.423\nsamples = 674\nvalue = [205, 469]'),
#  Text(0.34933333333333333, 0.575, 'X[7] <= 3.5\ngini = 0.01\nsamples = 206\nvalue = [205, 1]'),
#  Text(0.344, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3546666666666667, 0.525, 'gini = 0.0\nsamples = 205\nvalue = [205, 0]'),
#  Text(0.36, 0.575, 'gini = 0.0\nsamples = 468\nvalue = [0, 468]'),
#  Text(0.36533333333333334, 0.625, 'gini = 0.0\nsamples = 333\nvalue = [333, 0]'),
#  Text(0.38133333333333336, 0.675, 'X[9] <= 2.085\ngini = 0.209\nsamples = 1077\nvalue = [128, 949]'),
#  Text(0.376, 0.625, 'gini = 0.0\nsamples = 53\nvalue = [53, 0]'),
#  Text(0.38666666666666666, 0.625, 'X[7] <= 2.0\ngini = 0.136\nsamples = 1024\nvalue = [75, 949]'),
#  Text(0.38133333333333336, 0.575, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.392, 0.575, 'X[0] <= 6.435\ngini = 0.11\nsamples = 1008\nvalue = [59, 949]'),
#  Text(0.38666666666666666, 0.525, 'X[0] <= 1.735\ngini = 0.09\nsamples = 996\nvalue = [47, 949]'),
#  Text(0.376, 0.475, 'X[11] <= 2.5\ngini = 0.436\nsamples = 81\nvalue = [26, 55]'),
#  Text(0.37066666666666664, 0.425, 'gini = 0.0\nsamples = 55\nvalue = [0, 55]'),
#  Text(0.38133333333333336, 0.425, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.3973333333333333, 0.475, 'X[19] <= 2.5\ngini = 0.045\nsamples = 915\nvalue = [21, 894]'),
#  Text(0.392, 0.425, 'X[0] <= 5.685\ngini = 0.039\nsamples = 912\nvalue = [18, 894]'),
#  Text(0.37633333333333335, 0.375, 'X[0] <= 5.23\ngini = 0.025\nsamples = 877\nvalue = [11, 866]'),
#  Text(0.361, 0.325, 'X[3] <= 1.5\ngini = 0.019\nsamples = 831\nvalue = [8, 823]'),
#  Text(0.3463333333333333, 0.275, 'X[6] <= -0.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.341, 0.225, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.3516666666666667, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.37566666666666665, 0.275, 'X[0] <= 1.795\ngini = 0.015\nsamples = 818\nvalue = [6, 812]'),
#  Text(0.36233333333333334, 0.225, 'X[11] <= 2.5\ngini = 0.159\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.357, 0.175, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.36766666666666664, 0.175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.389, 0.225, 'X[7] <= 6.5\ngini = 0.01\nsamples = 795\nvalue = [4, 791]'),
#  Text(0.37833333333333335, 0.175, 'X[18] <= 1.5\ngini = 0.036\nsamples = 164\nvalue = [3, 161]'),
#  Text(0.373, 0.125, 'X[6] <= -0.5\ngini = 0.139\nsamples = 40\nvalue = [3, 37]'),
#  Text(0.36766666666666664, 0.075, 'gini = 0.0\nsamples = 37\nvalue = [0, 37]'),
#  Text(0.37833333333333335, 0.075, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.38366666666666666, 0.125, 'gini = 0.0\nsamples = 124\nvalue = [0, 124]'),
#  Text(0.39966666666666667, 0.175, 'X[0] <= 4.65\ngini = 0.003\nsamples = 631\nvalue = [1, 630]'),
#  Text(0.3943333333333333, 0.125, 'gini = 0.0\nsamples = 590\nvalue = [0, 590]'),
#  Text(0.405, 0.125, 'X[8] <= 4.085\ngini = 0.048\nsamples = 41\nvalue = [1, 40]'),
#  Text(0.39966666666666667, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4103333333333333, 0.075, 'gini = 0.0\nsamples = 40\nvalue = [0, 40]'),
#  Text(0.39166666666666666, 0.325, 'X[8] <= 4.085\ngini = 0.122\nsamples = 46\nvalue = [3, 43]'),
#  Text(0.3863333333333333, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.397, 0.275, 'gini = 0.0\nsamples = 43\nvalue = [0, 43]'),
#  Text(0.4076666666666667, 0.375, 'X[8] <= 4.265\ngini = 0.32\nsamples = 35\nvalue = [7, 28]'),
#  Text(0.4023333333333333, 0.325, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.413, 0.325, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.4026666666666667, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3973333333333333, 0.525, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.38133333333333336, 0.725, 'gini = 0.0\nsamples = 870\nvalue = [0, 870]'),
#  Text(0.45666666666666667, 0.875, 'X[8] <= 3.935\ngini = 0.493\nsamples = 2798\nvalue = [1560, 1238]'),
#  Text(0.41333333333333333, 0.825, 'X[9] <= 2.78\ngini = 0.259\nsamples = 1188\nvalue = [182, 1006]'),
#  Text(0.3973333333333333, 0.775, 'X[1] <= 2.5\ngini = 0.027\nsamples = 870\nvalue = [12, 858]'),
#  Text(0.392, 0.725, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.4026666666666667, 0.725, 'X[2] <= 8.0\ngini = 0.005\nsamples = 860\nvalue = [2, 858]'),
#  Text(0.3973333333333333, 0.675, 'gini = 0.0\nsamples = 858\nvalue = [0, 858]'),
#  Text(0.408, 0.675, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.42933333333333334, 0.775, 'X[7] <= 6.0\ngini = 0.498\nsamples = 318\nvalue = [170, 148]'),
#  Text(0.424, 0.725, 'X[5] <= 0.5\ngini = 0.051\nsamples = 152\nvalue = [4, 148]'),
#  Text(0.4186666666666667, 0.675, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.42933333333333334, 0.675, 'gini = 0.0\nsamples = 148\nvalue = [0, 148]'),
#  Text(0.43466666666666665, 0.725, 'gini = 0.0\nsamples = 166\nvalue = [166, 0]'),
#  Text(0.5, 0.825, 'X[5] <= 4.0\ngini = 0.247\nsamples = 1610\nvalue = [1378, 232]'),
#  Text(0.4693333333333333, 0.775, 'X[8] <= 4.445\ngini = 0.079\nsamples = 1279\nvalue = [1226, 53]'),
#  Text(0.44533333333333336, 0.725, 'X[3] <= 8.0\ngini = 0.486\nsamples = 113\nvalue = [66, 47]'),
#  Text(0.44, 0.675, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.45066666666666666, 0.675, 'X[0] <= 3.505\ngini = 0.441\nsamples = 70\nvalue = [23, 47]'),
#  Text(0.44, 0.625, 'X[19] <= 2.5\ngini = 0.156\nsamples = 47\nvalue = [4, 43]'),
#  Text(0.43466666666666665, 0.575, 'X[8] <= 3.995\ngini = 0.085\nsamples = 45\nvalue = [2, 43]'),
#  Text(0.42933333333333334, 0.525, 'X[1] <= 3.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.424, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.43466666666666665, 0.475, 'X[9] <= 6.085\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.42933333333333334, 0.425, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.44, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44, 0.525, 'gini = 0.0\nsamples = 36\nvalue = [0, 36]'),
#  Text(0.44533333333333336, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4613333333333333, 0.625, 'X[2] <= 3.5\ngini = 0.287\nsamples = 23\nvalue = [19, 4]'),
#  Text(0.456, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4666666666666667, 0.575, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.49333333333333335, 0.725, 'X[8] <= 4.66\ngini = 0.01\nsamples = 1166\nvalue = [1160, 6]'),
#  Text(0.47733333333333333, 0.675, 'X[3] <= 9.5\ngini = 0.194\nsamples = 46\nvalue = [41, 5]'),
#  Text(0.472, 0.625, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.4826666666666667, 0.625, 'X[1] <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.47733333333333333, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.488, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5093333333333333, 0.675, 'X[0] <= 1.375\ngini = 0.002\nsamples = 1120\nvalue = [1119, 1]'),
#  Text(0.504, 0.625, 'X[9] <= 4.52\ngini = 0.062\nsamples = 31\nvalue = [30, 1]'),
#  Text(0.49866666666666665, 0.575, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.5093333333333333, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5146666666666667, 0.625, 'gini = 0.0\nsamples = 1089\nvalue = [1089, 0]'),
#  Text(0.5306666666666666, 0.775, 'X[2] <= 4.5\ngini = 0.497\nsamples = 331\nvalue = [152, 179]'),
#  Text(0.5253333333333333, 0.725, 'X[7] <= 10.5\ngini = 0.013\nsamples = 153\nvalue = [152, 1]'),
#  Text(0.52, 0.675, 'gini = 0.0\nsamples = 152\nvalue = [152, 0]'),
#  Text(0.5306666666666666, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.536, 0.725, 'gini = 0.0\nsamples = 178\nvalue = [0, 178]'),
#  Text(0.8167916666666667, 0.925, 'X[16] <= 6.5\ngini = 0.496\nsamples = 17558\nvalue = [9568, 7990]'),
#  Text(0.8114583333333333, 0.875, 'X[10] <= 0.5\ngini = 0.492\nsamples = 16984\nvalue = [9568, 7416]'),
#  Text(0.6549166666666667, 0.825, 'X[5] <= 1.5\ngini = 0.478\nsamples = 14663\nvalue = [8872, 5791]'),
#  Text(0.5746666666666667, 0.775, 'X[2] <= -0.5\ngini = 0.5\nsamples = 5611\nvalue = [2734, 2877]'),
#  Text(0.5546666666666666, 0.725, 'X[9] <= 13.595\ngini = 0.416\nsamples = 1877\nvalue = [1324, 553]'),
#  Text(0.5413333333333333, 0.675, 'X[12] <= 11.5\ngini = 0.492\nsamples = 938\nvalue = [408, 530]'),
#  Text(0.536, 0.625, 'X[5] <= 0.5\ngini = 0.498\nsamples = 764\nvalue = [408, 356]'),
#  Text(0.5253333333333333, 0.575, 'X[1] <= 5.5\ngini = 0.124\nsamples = 302\nvalue = [282, 20]'),
#  Text(0.52, 0.525, 'X[9] <= 9.74\ngini = 0.357\nsamples = 86\nvalue = [66, 20]'),
#  Text(0.5146666666666667, 0.475, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.5253333333333333, 0.475, 'gini = 0.0\nsamples = 66\nvalue = [66, 0]'),
#  Text(0.5306666666666666, 0.525, 'gini = 0.0\nsamples = 216\nvalue = [216, 0]'),
#  Text(0.5466666666666666, 0.575, 'X[11] <= 2.0\ngini = 0.397\nsamples = 462\nvalue = [126, 336]'),
#  Text(0.5413333333333333, 0.525, 'X[8] <= 2.695\ngini = 0.229\nsamples = 387\nvalue = [51, 336]'),
#  Text(0.536, 0.475, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(0.5466666666666666, 0.475, 'X[9] <= 9.06\ngini = 0.097\nsamples = 354\nvalue = [18, 336]'),
#  Text(0.5413333333333333, 0.425, 'X[7] <= 9.0\ngini = 0.497\nsamples = 39\nvalue = [18, 21]'),
#  Text(0.536, 0.375, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.5466666666666666, 0.375, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.552, 0.425, 'gini = 0.0\nsamples = 315\nvalue = [0, 315]'),
#  Text(0.552, 0.525, 'gini = 0.0\nsamples = 75\nvalue = [75, 0]'),
#  Text(0.5466666666666666, 0.625, 'gini = 0.0\nsamples = 174\nvalue = [0, 174]'),
#  Text(0.568, 0.675, 'X[12] <= 11.5\ngini = 0.048\nsamples = 939\nvalue = [916, 23]'),
#  Text(0.5626666666666666, 0.625, 'X[7] <= 6.5\ngini = 0.021\nsamples = 926\nvalue = [916, 10]'),
#  Text(0.5573333333333333, 0.575, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.568, 0.575, 'gini = 0.0\nsamples = 916\nvalue = [916, 0]'),
#  Text(0.5733333333333334, 0.625, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.5946666666666667, 0.725, 'X[17] <= 2.5\ngini = 0.47\nsamples = 3734\nvalue = [1410, 2324]'),
#  Text(0.5893333333333334, 0.675, 'X[3] <= 0.5\ngini = 0.431\nsamples = 3387\nvalue = [1063, 2324]'),
#  Text(0.584, 0.625, 'gini = 0.0\nsamples = 262\nvalue = [262, 0]'),
#  Text(0.5946666666666667, 0.625, 'X[10] <= -0.5\ngini = 0.381\nsamples = 3125\nvalue = [801, 2324]'),
#  Text(0.5893333333333334, 0.575, 'X[12] <= 10.0\ngini = 0.331\nsamples = 2940\nvalue = [616, 2324]'),
#  Text(0.576, 0.525, 'X[0] <= 4.8\ngini = 0.023\nsamples = 1374\nvalue = [16, 1358]'),
#  Text(0.5706666666666667, 0.475, 'X[6] <= -0.5\ngini = 0.498\nsamples = 34\nvalue = [16, 18]'),
#  Text(0.5653333333333334, 0.425, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.576, 0.425, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.5813333333333334, 0.475, 'gini = 0.0\nsamples = 1340\nvalue = [0, 1340]'),
#  Text(0.6026666666666667, 0.525, 'X[8] <= 6.755\ngini = 0.473\nsamples = 1566\nvalue = [600, 966]'),
#  Text(0.592, 0.475, 'X[5] <= -0.5\ngini = 0.371\nsamples = 752\nvalue = [567, 185]'),
#  Text(0.5866666666666667, 0.425, 'gini = 0.0\nsamples = 97\nvalue = [0, 97]'),
#  Text(0.5973333333333334, 0.425, 'X[9] <= 21.845\ngini = 0.233\nsamples = 655\nvalue = [567, 88]'),
#  Text(0.592, 0.375, 'X[0] <= 3.765\ngini = 0.093\nsamples = 596\nvalue = [567, 29]'),
#  Text(0.5813333333333334, 0.325, 'X[18] <= 0.5\ngini = 0.067\nsamples = 29\nvalue = [1, 28]'),
#  Text(0.576, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5866666666666667, 0.275, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.6026666666666667, 0.325, 'X[9] <= 19.68\ngini = 0.004\nsamples = 567\nvalue = [566, 1]'),
#  Text(0.5973333333333334, 0.275, 'gini = 0.0\nsamples = 565\nvalue = [565, 0]'),
#  Text(0.608, 0.275, 'X[1] <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6026666666666667, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6133333333333333, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6026666666666667, 0.375, 'gini = 0.0\nsamples = 59\nvalue = [0, 59]'),
#  Text(0.6133333333333333, 0.475, 'X[5] <= 0.5\ngini = 0.078\nsamples = 814\nvalue = [33, 781]'),
#  Text(0.608, 0.425, 'gini = 0.0\nsamples = 670\nvalue = [0, 670]'),
#  Text(0.6186666666666667, 0.425, 'X[9] <= 22.29\ngini = 0.353\nsamples = 144\nvalue = [33, 111]'),
#  Text(0.6133333333333333, 0.375, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(0.624, 0.375, 'gini = 0.0\nsamples = 111\nvalue = [0, 111]'),
#  Text(0.6, 0.575, 'gini = 0.0\nsamples = 185\nvalue = [185, 0]'),
#  Text(0.6, 0.675, 'gini = 0.0\nsamples = 347\nvalue = [347, 0]'),
#  Text(0.7351666666666666, 0.775, 'X[1] <= 3.5\ngini = 0.437\nsamples = 9052\nvalue = [6138, 2914]'),
#  Text(0.6746666666666666, 0.725, 'X[2] <= 1.5\ngini = 0.5\nsamples = 3576\nvalue = [1791, 1785]'),
#  Text(0.6426666666666667, 0.675, 'X[9] <= 16.125\ngini = 0.4\nsamples = 1413\nvalue = [390, 1023]'),
#  Text(0.6293333333333333, 0.625, 'X[11] <= 4.0\ngini = 0.068\nsamples = 594\nvalue = [21, 573]'),
#  Text(0.624, 0.575, 'X[12] <= 1.5\ngini = 0.01\nsamples = 576\nvalue = [3, 573]'),
#  Text(0.6186666666666667, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6293333333333333, 0.525, 'X[7] <= 1.0\ngini = 0.003\nsamples = 574\nvalue = [1, 573]'),
#  Text(0.624, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6346666666666667, 0.475, 'gini = 0.0\nsamples = 573\nvalue = [0, 573]'),
#  Text(0.6346666666666667, 0.575, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.656, 0.625, 'X[1] <= 2.5\ngini = 0.495\nsamples = 819\nvalue = [369, 450]'),
#  Text(0.6453333333333333, 0.575, 'X[6] <= -0.5\ngini = 0.226\nsamples = 362\nvalue = [315, 47]'),
#  Text(0.64, 0.525, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(0.6506666666666666, 0.525, 'X[3] <= 10.5\ngini = 0.006\nsamples = 316\nvalue = [315, 1]'),
#  Text(0.6453333333333333, 0.475, 'gini = 0.0\nsamples = 315\nvalue = [315, 0]'),
#  Text(0.656, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.575, 'X[11] <= 0.0\ngini = 0.208\nsamples = 457\nvalue = [54, 403]'),
#  Text(0.6613333333333333, 0.525, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]'),
#  Text(0.672, 0.525, 'gini = 0.0\nsamples = 403\nvalue = [0, 403]'),
#  Text(0.7066666666666667, 0.675, 'X[11] <= 6.5\ngini = 0.456\nsamples = 2163\nvalue = [1401, 762]'),
#  Text(0.7013333333333334, 0.625, 'X[11] <= 1.0\ngini = 0.35\nsamples = 1810\nvalue = [1401, 409]'),
#  Text(0.696, 0.575, 'X[7] <= 6.0\ngini = 0.499\nsamples = 853\nvalue = [444, 409]'),
#  Text(0.6826666666666666, 0.525, 'X[1] <= 1.0\ngini = 0.055\nsamples = 320\nvalue = [311, 9]'),
#  Text(0.6773333333333333, 0.475, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.688, 0.475, 'gini = 0.0\nsamples = 311\nvalue = [311, 0]'),
#  Text(0.7093333333333334, 0.525, 'X[18] <= 2.5\ngini = 0.375\nsamples = 533\nvalue = [133, 400]'),
#  Text(0.6986666666666667, 0.475, 'X[2] <= 9.5\ngini = 0.183\nsamples = 442\nvalue = [45, 397]'),
#  Text(0.6933333333333334, 0.425, 'X[15] <= 0.5\ngini = 0.119\nsamples = 424\nvalue = [27, 397]'),
#  Text(0.688, 0.375, 'X[9] <= 22.52\ngini = 0.095\nsamples = 418\nvalue = [21, 397]'),
#  Text(0.6826666666666666, 0.325, 'gini = 0.0\nsamples = 339\nvalue = [0, 339]'),
#  Text(0.6933333333333334, 0.325, 'X[12] <= 8.5\ngini = 0.39\nsamples = 79\nvalue = [21, 58]'),
#  Text(0.688, 0.275, 'gini = 0.0\nsamples = 58\nvalue = [0, 58]'),
#  Text(0.6986666666666667, 0.275, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.6986666666666667, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.704, 0.425, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.72, 0.475, 'X[6] <= -0.5\ngini = 0.064\nsamples = 91\nvalue = [88, 3]'),
#  Text(0.7146666666666667, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7253333333333334, 0.425, 'gini = 0.0\nsamples = 88\nvalue = [88, 0]'),
#  Text(0.7066666666666667, 0.575, 'gini = 0.0\nsamples = 957\nvalue = [957, 0]'),
#  Text(0.712, 0.625, 'gini = 0.0\nsamples = 353\nvalue = [0, 353]'),
#  Text(0.7956666666666666, 0.725, 'X[5] <= 4.5\ngini = 0.327\nsamples = 5476\nvalue = [4347, 1129]'),
#  Text(0.7593333333333333, 0.675, 'X[2] <= 2.5\ngini = 0.235\nsamples = 3768\nvalue = [3255, 513]'),
#  Text(0.7413333333333333, 0.625, 'X[2] <= 0.5\ngini = 0.447\nsamples = 1409\nvalue = [933, 476]'),
#  Text(0.7306666666666667, 0.575, 'X[0] <= 10.295\ngini = 0.207\nsamples = 964\nvalue = [851, 113]'),
#  Text(0.7253333333333334, 0.525, 'gini = 0.0\nsamples = 850\nvalue = [850, 0]'),
#  Text(0.736, 0.525, 'X[4] <= 0.5\ngini = 0.017\nsamples = 114\nvalue = [1, 113]'),
#  Text(0.7306666666666667, 0.475, 'gini = 0.0\nsamples = 113\nvalue = [0, 113]'),
#  Text(0.7413333333333333, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.752, 0.575, 'X[16] <= 0.0\ngini = 0.301\nsamples = 445\nvalue = [82, 363]'),
#  Text(0.7466666666666667, 0.525, 'gini = 0.0\nsamples = 82\nvalue = [82, 0]'),
#  Text(0.7573333333333333, 0.525, 'gini = 0.0\nsamples = 363\nvalue = [0, 363]'),
#  Text(0.7773333333333333, 0.625, 'X[3] <= 4.0\ngini = 0.031\nsamples = 2359\nvalue = [2322, 37]'),
#  Text(0.772, 0.575, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.7826666666666666, 0.575, 'X[9] <= 8.545\ngini = 0.019\nsamples = 2345\nvalue = [2322, 23]'),
#  Text(0.768, 0.525, 'X[18] <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.7626666666666667, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7733333333333333, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7973333333333333, 0.525, 'X[0] <= 18.58\ngini = 0.015\nsamples = 2336\nvalue = [2318, 18]'),
#  Text(0.784, 0.475, 'X[9] <= 9.045\ngini = 0.005\nsamples = 2226\nvalue = [2220, 6]'),
#  Text(0.7733333333333333, 0.425, 'X[18] <= 0.5\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.768, 0.375, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.7786666666666666, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7946666666666666, 0.425, 'X[0] <= 14.405\ngini = 0.004\nsamples = 2197\nvalue = [2193, 4]'),
#  Text(0.7893333333333333, 0.375, 'gini = 0.0\nsamples = 2076\nvalue = [2076, 0]'),
#  Text(0.8, 0.375, 'X[2] <= 7.5\ngini = 0.064\nsamples = 121\nvalue = [117, 4]'),
#  Text(0.7946666666666666, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8053333333333333, 0.325, 'gini = 0.0\nsamples = 117\nvalue = [117, 0]'),
#  Text(0.8106666666666666, 0.475, 'X[8] <= 9.605\ngini = 0.194\nsamples = 110\nvalue = [98, 12]'),
#  Text(0.8053333333333333, 0.425, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.816, 0.425, 'gini = 0.0\nsamples = 98\nvalue = [98, 0]'),
#  Text(0.832, 0.675, 'X[12] <= 11.5\ngini = 0.461\nsamples = 1708\nvalue = [1092, 616]'),
#  Text(0.8266666666666667, 0.625, 'X[2] <= 2.0\ngini = 0.4\nsamples = 1508\nvalue = [1092, 416]'),
#  Text(0.8133333333333334, 0.575, 'X[6] <= -0.5\ngini = 0.003\nsamples = 641\nvalue = [640, 1]'),
#  Text(0.808, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8186666666666667, 0.525, 'gini = 0.0\nsamples = 640\nvalue = [640, 0]'),
#  Text(0.84, 0.575, 'X[5] <= 5.5\ngini = 0.499\nsamples = 867\nvalue = [452, 415]'),
#  Text(0.8293333333333334, 0.525, 'X[12] <= 9.5\ngini = 0.257\nsamples = 376\nvalue = [57, 319]'),
#  Text(0.824, 0.475, 'gini = 0.0\nsamples = 314\nvalue = [0, 314]'),
#  Text(0.8346666666666667, 0.475, 'X[17] <= 0.0\ngini = 0.148\nsamples = 62\nvalue = [57, 5]'),
#  Text(0.8293333333333334, 0.425, 'gini = 0.0\nsamples = 57\nvalue = [57, 0]'),
#  Text(0.84, 0.425, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8506666666666667, 0.525, 'X[6] <= 0.5\ngini = 0.315\nsamples = 491\nvalue = [395, 96]'),
#  Text(0.8453333333333334, 0.475, 'gini = 0.0\nsamples = 395\nvalue = [395, 0]'),
#  Text(0.856, 0.475, 'gini = 0.0\nsamples = 96\nvalue = [0, 96]'),
#  Text(0.8373333333333334, 0.625, 'gini = 0.0\nsamples = 200\nvalue = [0, 200]'),
#  Text(0.968, 0.825, 'X[18] <= 2.5\ngini = 0.42\nsamples = 2321\nvalue = [696, 1625]'),
#  Text(0.9626666666666667, 0.775, 'X[0] <= 15.955\ngini = 0.292\nsamples = 1976\nvalue = [351, 1625]'),
#  Text(0.936, 0.725, 'X[0] <= 12.005\ngini = 0.127\nsamples = 1672\nvalue = [114, 1558]'),
#  Text(0.9093333333333333, 0.675, 'X[8] <= 20.695\ngini = 0.023\nsamples = 1304\nvalue = [15, 1289]'),
#  Text(0.904, 0.625, 'X[0] <= 11.035\ngini = 0.021\nsamples = 1303\nvalue = [14, 1289]'),
#  Text(0.8826666666666667, 0.575, 'X[19] <= 2.5\ngini = 0.007\nsamples = 1203\nvalue = [4, 1199]'),
#  Text(0.872, 0.525, 'X[0] <= 10.325\ngini = 0.002\nsamples = 1168\nvalue = [1, 1167]'),
#  Text(0.8666666666666667, 0.475, 'gini = 0.0\nsamples = 1062\nvalue = [0, 1062]'),
#  Text(0.8773333333333333, 0.475, 'X[0] <= 10.335\ngini = 0.019\nsamples = 106\nvalue = [1, 105]'),
#  Text(0.872, 0.425, 'X[14] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8666666666666667, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8773333333333333, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8826666666666667, 0.425, 'gini = 0.0\nsamples = 104\nvalue = [0, 104]'),
#  Text(0.8933333333333333, 0.525, 'X[15] <= 0.5\ngini = 0.157\nsamples = 35\nvalue = [3, 32]'),
#  Text(0.888, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8986666666666666, 0.475, 'gini = 0.0\nsamples = 32\nvalue = [0, 32]'),
#  Text(0.9253333333333333, 0.575, 'X[6] <= -0.5\ngini = 0.18\nsamples = 100\nvalue = [10, 90]'),
#  Text(0.9146666666666666, 0.525, 'X[0] <= 11.095\ngini = 0.022\nsamples = 89\nvalue = [1, 88]'),
#  Text(0.9093333333333333, 0.475, 'X[11] <= 3.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.904, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9146666666666666, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.92, 0.475, 'gini = 0.0\nsamples = 84\nvalue = [0, 84]'),
#  Text(0.936, 0.525, 'X[10] <= 3.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.9306666666666666, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9413333333333334, 0.475, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.9146666666666666, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9626666666666667, 0.675, 'X[6] <= -0.5\ngini = 0.393\nsamples = 368\nvalue = [99, 269]'),
#  Text(0.9573333333333334, 0.625, 'X[5] <= -0.5\ngini = 0.23\nsamples = 310\nvalue = [41, 269]'),
#  Text(0.952, 0.575, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.9626666666666667, 0.575, 'X[2] <= 0.5\ngini = 0.14\nsamples = 291\nvalue = [22, 269]'),
#  Text(0.9573333333333334, 0.525, 'X[11] <= 3.0\ngini = 0.444\nsamples = 33\nvalue = [22, 11]'),
#  Text(0.952, 0.475, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.9626666666666667, 0.475, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.968, 0.525, 'gini = 0.0\nsamples = 258\nvalue = [0, 258]'),
#  Text(0.968, 0.625, 'gini = 0.0\nsamples = 58\nvalue = [58, 0]'),
#  Text(0.9893333333333333, 0.725, 'X[14] <= 1.5\ngini = 0.344\nsamples = 304\nvalue = [237, 67]'),
#  Text(0.984, 0.675, 'X[12] <= 11.5\ngini = 0.173\nsamples = 262\nvalue = [237, 25]'),
#  Text(0.9786666666666667, 0.625, 'gini = 0.0\nsamples = 237\nvalue = [237, 0]'),
#  Text(0.9893333333333333, 0.625, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.9946666666666667, 0.675, 'gini = 0.0\nsamples = 42\nvalue = [0, 42]'),
#  Text(0.9733333333333334, 0.775, 'gini = 0.0\nsamples = 345\nvalue = [345, 0]'),
#  Text(0.822125, 0.875, 'gini = 0.0\nsamples = 574\nvalue = [0, 574]')]

# %%
import graphviz
dot_data = tree.export_graphviz(clf, out_file=None)
graph = graphviz.Source(dot_data)
graph.render("mushrooms")
# Out:
# 'mushrooms.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, feature_names=x.columns.tolist(),class_names=y,filled=True, rounded=True,special_characters=True)
graph = graphviz.Source(dot_data)
graph
